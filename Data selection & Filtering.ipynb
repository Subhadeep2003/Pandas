# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %% [markdown]
# #Selecting Rows & Columns
# ##Selecting Columns

# %%
df["Actor"]        # Single column (as Series)
# Out:
# 0         Shah Rukh Khan
# 1            Salman Khan
# 2             Aamir Khan
# 3          Ranbir Kapoor
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 9          Kartik Aaryan
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
df["Actor"] [3]
# Out:
# 'Ranbir Kapoor'

# %%
type(df["Actor"])
# Out:
# pandas.core.series.Series

# %%
df[["Film", "Year","IMDb"]]     # Multiple columns (as DataFrame)
# Out:
#                         Film  Year  IMDb
# 0                    Pathaan  2023   7.2
# 1            Tiger Zinda Hai  2017   6.0
# 2                     Dangal  2016   8.4
# 3                 Brahmastra  2022   5.6
# 4                  Padmaavat  2018   7.0
# 5                  Andhadhun  2018   8.3
# 6                      Stree  2018   7.5
# 7                        War  2019   6.5
# 8                 Good Newwz  2019   7.0
# 9          Bhool Bhulaiyaa 2  2022   5.9
# 10     Badrinath Ki Dulhania  2017   6.1
# 11  Uri: The Surgical Strike  2019   8.2

# %%
df#original dataset will be remain same
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %% [markdown]
# Selecting Rows by Index

# %%
df.loc[0]# First row (by label)
# Out:
# Actor                   Shah Rukh Khan
# Film                           Pathaan
# Year                              2023
# Genre                           Action
# BoxOffice(INR Crore)              1050
# IMDb                               7.2
# Name: 0, dtype: object

# %%
df.iloc[0]# First row (by position)
# Out:
# Actor                   Shah Rukh Khan
# Film                           Pathaan
# Year                              2023
# Genre                           Action
# BoxOffice(INR Crore)              1050
# IMDb                               7.2
# Name: 0, dtype: object

# %% [markdown]
# Select Specific Rows and Columns

# %%
df.loc[10,'Genre']# Value at row 10, column 'Genre'
# Out:
# 'Romantic Comedy'

# %%
df.iloc[10,3]# Value at row 10, column at index 3
# Out:
# 'Romantic Comedy'

# %%
 # Rows 0 to 2, selected columns
df.loc[0:2,["Actor","IMDb","Film"]]#Using loc last index inclusive
# Out:
#             Actor  IMDb             Film
# 0  Shah Rukh Khan   7.2          Pathaan
# 1     Salman Khan   6.0  Tiger Zinda Hai
# 2      Aamir Khan   8.4           Dangal

# %%
# Rows and cols by index position
df.iloc[0:2,0:2]#using iloc last index exclusive
# Out:
#             Actor             Film
# 0  Shah Rukh Khan          Pathaan
# 1     Salman Khan  Tiger Zinda Hai

# %%
df.at[0,"Actor"]#For access a particular cell or element
# Out:
# 'Shah Rukh Khan'

# %%
df.iat[0,0]
# Out:
# 'Shah Rukh Khan'

# %% [markdown]
# Filtering with Conditions

# %%
df[df["IMDb"]>7]
# Out:
#                  Actor                      Film  Year          Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023         Action
# 2           Aamir Khan                    Dangal  2016      Biography
# 5   Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6        Rajkummar Rao                     Stree  2018  Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 5                    111   8.3
# 6                    180   7.5
# 11                   342   8.2

# %%
df[(df["IMDb"]>7) & (df['Year']>2018)]
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 11                   342   8.2

# %%
df[(df["IMDb"]>7) | (df['Year']>2018)]
# Out:
#                  Actor                      Film  Year          Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023         Action
# 2           Aamir Khan                    Dangal  2016      Biography
# 3        Ranbir Kapoor                Brahmastra  2022        Fantasy
# 5   Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6        Rajkummar Rao                     Stree  2018  Horror Comedy
# 7       Hrithik Roshan                       War  2019         Action
# 8         Akshay Kumar                Good Newwz  2019         Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 3                    431   5.6
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# ...

# %%
df.query("Year > 2019")
# Out:
#             Actor               Film  Year          Genre  \
# 0  Shah Rukh Khan            Pathaan  2023         Action
# 3   Ranbir Kapoor         Brahmastra  2022        Fantasy
# 9   Kartik Aaryan  Bhool Bhulaiyaa 2  2022  Horror Comedy
#
#    BoxOffice(INR Crore)  IMDb
# 0                  1050   7.2
# 3                   431   5.6
# 9                   266   5.9

# %%
df.query("Year > 2018 and IMDb>6")
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 8     Akshay Kumar                Good Newwz  2019  Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %%
df2 = df[["Actor","Film","IMDb"]]

# %%
df2
# Out:
#                  Actor                      Film  IMDb
# 0       Shah Rukh Khan                   Pathaan   7.2
# 1          Salman Khan           Tiger Zinda Hai   6.0
# 2           Aamir Khan                    Dangal   8.4
# 3        Ranbir Kapoor                Brahmastra   5.6
# 4        Ranveer Singh                 Padmaavat   7.0
# 5   Ayushmann Khurrana                 Andhadhun   8.3
# 6        Rajkummar Rao                     Stree   7.5
# 7       Hrithik Roshan                       War   6.5
# 8         Akshay Kumar                Good Newwz   7.0
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2   5.9
# 10        Varun Dhawan     Badrinath Ki Dulhania   6.1
# 11       Vicky Kaushal  Uri: The Surgical Strike   8.2

# %%
df2.loc[0,"Actor"] = "Subh"

# %%
df2
# Out:
#                  Actor                      Film  IMDb
# 0                 Subh                   Pathaan   7.2
# 1          Salman Khan           Tiger Zinda Hai   6.0
# 2           Aamir Khan                    Dangal   8.4
# 3        Ranbir Kapoor                Brahmastra   5.6
# 4        Ranveer Singh                 Padmaavat   7.0
# 5   Ayushmann Khurrana                 Andhadhun   8.3
# 6        Rajkummar Rao                     Stree   7.5
# 7       Hrithik Roshan                       War   6.5
# 8         Akshay Kumar                Good Newwz   7.0
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2   5.9
# 10        Varun Dhawan     Badrinath Ki Dulhania   6.1
# 11       Vicky Kaushal  Uri: The Surgical Strike   8.2

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...
